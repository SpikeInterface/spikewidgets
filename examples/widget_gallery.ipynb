# %% [markdown]
# # Example of available widgets

# %%
import spikeextractors as se
import spiketoolkit as st
import spikewidgets as sw
# %matplotlib notebook

# %%
rec, sort = se.example_datasets.toy_example(num_channels=4, duration=300)

# %%
sw.plot_timeseries(rec)

# %%
sw.plot_electrode_geometry(rec)

# %%
sw.plot_unit_waveforms(sort, rec)

# %%
sw.plot_crosscorrelograms(sort, bin_size=1, window=10)

# %%
sw.plot_rasters(sort)

# %%
sw.plot_isi_distribution(sort, bin_size=3, max_isi=100)

# %%
sc = st.comparison.compare_two_sorters(sort, sort)

# %%
sw.plot_confusion_matrix(sc, count_text=False)

# %%
msc = st.comparison.compare_multiple_sorters([sort, sort, sort])

# %%
sw.plot_multicomp_graph(msc, edge_cmap='viridis', node_cmap='rainbow', draw_labels=False)
